# %% [markdown]
# Here is your upgraded **master prompt** with all four modules, shaped like a real startup product:
#
# ---
#
# > **Prompt:**
# >
# > Build a full-stack AI product named **DivyaPath AI** – a divine, intelligent guidance system for students that connects academics, skills, emotions, and career direction.
# >
# > The system must contain **four integrated modules**:
# >
# > ---
# >
# > ## 🔹 Module 1: Student Performance Predictor
# >
# > * Use a Kaggle “Student Performance” dataset.
# > * Perform data cleaning, EDA, and feature engineering.
# > * Train ML models (Logistic Regression, Random Forest, XGBoost).
# > * Predict:
# >
# >   * Pass/Fail or Grade Range
# >   * Risk Score (0–100)
# > * Show:
# >
# >   * Weak subjects
# >   * Feature importance
# >   * Personalized academic improvement tips
# >
# > ---
# >
# > ## 🔹 Module 2: Resume Skill Analyzer
# >
# > * Accept resume in PDF or text format.
# > * Extract skills using NLP (spaCy / embeddings).
# > * Accept a target job role (e.g., Data Analyst).
# > * Compare resume with job description dataset.
# > * Output:
# >
# >   * Extracted skills
# >   * Match percentage
# >   * Missing skills
# >   * Resume improvement suggestions
# >   * Corrected / optimized resume text
# >
# > ---
# >
# > ## 🔹 Module 3: Career Roadmap Generator
# >
# > Use the **corrected resume + academic prediction** to build a career path.
# >
# > * Inputs:
# >
# >   * Student performance result
# >   * Resume analysis output
# >   * Target career domain
# > * Outputs:
# >
# >   * Career readiness score
# >   * Best-fit roles (current + future)
# >   * 3-month, 6-month, and 12-month roadmap
# >   * Skills to learn (ordered by priority)
# >   * Subject focus plan (based on weak areas)
# >   * Daily/weekly learning structure
# >
# > Example:
# > “You are 45% ready for a Data Analyst role.
# > In 3 months, focus on SQL and Python.
# > In 6 months, add Statistics and Power BI.
# > In 12 months, build 3 real projects and apply for internships.”
# >
# > ---
# >
# > ## 🔹 Module 4: Mood-Based Song Recommendation
# >
# > * Use webcam or uploaded image to detect facial expression.
# > * Classify mood: Happy, Sad, Stressed, Motivated, Tired, Confident.
# > * Use a simple CNN or pre-trained emotion model.
# > * Recommend:
# >
# >   * 3–5 songs based on mood
# >   * Category: Motivation, Calm, Focus, Energy
# > * Optionally include Hindi + English songs.
# >
# > Purpose:
# >
# > * Support mental state
# > * Improve focus and emotional balance
# > * Make the system feel human and caring
# >
# > ---
# >
# > ## 🔮 Final Combined Output (DivyaPath Intelligence)
# >
# > For each student, the system should generate:
# >
# > * Academic prediction
# > * Resume analysis
# > * Career roadmap
# > * Emotional state + music guidance
# >
# > Example Final Message:
# >
# > “You have a 63% chance of scoring above average.
# > You are weak in DBMS and Python.
# > Your resume matches 48% with Data Analyst roles.
# > In the next 3 months, focus on SQL and Pandas.
# > Your current mood seems stressed.
# > Here are 3 calm-focus songs to help you reset.”
# >
# > ---
# >
# > ## Tech Stack
# >
# > * Python, Pandas, NumPy
# > * Scikit-learn
# > * spaCy / Transformers
# > * OpenCV / Emotion Detection Model
# > * FastAPI Backend
# > * Streamlit / React Frontend
# > * SQLite / PostgreSQL
# >
# > Create:
# >
# > * Clean architecture
# > * ML training scripts
# > * API endpoints
# > * Streamlit UI
# > * Dashboards
# > * Proper README & documentation
# >
# > The final product must feel like a real EdTech + AI wellness startup, not a college assignment.
#
# This version makes **DivyaPath AI** unique in India.
# It blends *career, academics, skills, and emotions* in one system.
# That’s rare and powerful for interviews and portfolios.
